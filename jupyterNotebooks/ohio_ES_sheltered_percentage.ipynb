# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
county_names = ['Cincinnati/Hamilton', 'Toledo/Lucas', 'Cleveland/Cuyahoga', 'Columbus/Franklin', 'Youngstown/Mahoning', 
               'Dayton, Kettering/Montgomery', 'Akron, Barberton/Summit', 'Ohio Balance of State', 'Canton, Massillon, Alliance/Stark']

county_sheltered_ratios = [[],[],[],[],[],[],[],[],[]]

county_name_ratios = dict(zip(county_names, county_sheltered_ratios))

# %%
year = np.arange(2007,2022)

# loop to iterate and find es_sheltered / total homeless
for i in year:
    yr = str(i)
    
    # extract excel
    homeless_pop = pd.read_excel('data/2007-2021-PIT-Counts-by-CoC.xlsx', sheet_name = yr)
    
    # define attribute title in this loop
    overall_homeless = 'Overall Homeless, ' + yr
    sheltered_es = 'Sheltered ES Homeless, ' + yr
    
    # select columns
    pop_and_shelter = homeless_pop[['CoC Number','CoC Name', overall_homeless , sheltered_es]]
    
    # filter to Ohio county only
    oh_filter = pop_and_shelter['CoC Number'].str.contains('OH', case = False, na=False)
    oh_county = pop_and_shelter[oh_filter]
    
    # calculate the ratio for each year
    oh_county['sheltered es ratio'] = oh_county[sheltered_es] / pd.to_numeric(oh_county[overall_homeless])
    
    # add ratio into the arrays    
    index = 0
    for z in oh_county["sheltered es ratio"]:
        county_sheltered_ratios[index].append(z)
        index += 1
    
    # print the ratio for each year
    print("Year of Interest:" + yr)
    print(oh_county[['CoC Name','sheltered es ratio']])
    print("__________________________")
# Out:
# /opt/tljh/user/lib/python3.7/site-packages/ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Year of Interest:2007
#                                          CoC Name  sheltered es ratio
# 281                Cincinnati/Hamilton County CoC            0.615679
# 282                       Toledo/Lucas County CoC            0.425503
# 283                 Cleveland/Cuyahoga County CoC            0.581693
# 284                  Columbus/Franklin County CoC            0.823015
# 285                Youngstown/Mahoning County CoC            0.385542
# 286       Dayton, Kettering/Montgomery County CoC            0.686624
# 287            Akron, Barberton/Summit County CoC            0.344660
# 288                     Ohio Balance of State CoC            0.335132
# 289  Canton, Massillon, Alliance/Stark County CoC            0.436567
# __________________________
# /opt/tljh/user/lib/python3.7/site-packages/ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Year of Interest:2008
#                                          CoC Name  sheltered es ratio
# 277                Cincinnati/Hamilton County CoC            0.566308
# 278                       Toledo/Lucas County CoC            0.369135
# 279                 Cleveland/Cuyahoga County CoC            0.557092
# 280                  Columbus/Franklin County CoC            0.812081
# 281                Youngstown/Mahoning County CoC            0.394068
# 282       Dayton, Kettering/Montgomery County CoC            0.723934
# 283            Akron, Barberton/Summit County CoC            0.439189
# 284                     Ohio Balance of State CoC            0.342762
# 285  Canton, Massillon, Alliance/Stark County CoC            0.229923
# __________________________
# /opt/tljh/user/lib/python3.7/site-packages/ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Year of Interest:2009
#                                          CoC Name  sheltered es ratio
# 278                Cincinnati/Hamilton County CoC            0.601754
# 279                       Toledo/Lucas County CoC            0.432804
# 280                 Cleveland/Cuyahoga County CoC            0.544723
# 281                  Columbus/Franklin County CoC            0.824135
# 282                Youngstown/Mahoning County CoC            0.366120
# 283       Dayton, Kettering/Montgomery County CoC            0.683393
# 284            Akron, Barberton/Summit County CoC            0.398780
# 285                     Ohio Balance of State CoC            0.345912
# 286  Canton, Massillon, Alliance/Stark County CoC            0.421951
# __________________________
# /opt/tljh/user/lib/python3.7/site-packages/ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Year of Interest:2010
#                                          CoC Name  sheltered es ratio
# 278                Cincinnati/Hamilton County CoC            0.551690
# 279                       Toledo/Lucas County CoC            0.502028
# 280                 Cleveland/Cuyahoga County CoC            0.531607
# 281                  Columbus/Franklin County CoC            0.795963
# 282                Youngstown/Mahoning County CoC            0.497268
# 283       Dayton, Kettering/Montgomery County CoC            0.626697
# 284            Akron, Barberton/Summit County CoC            0.367870
# 285                     Ohio Balance of State CoC            0.352799
# 286  Canton, Massillon, Alliance/Stark County CoC            0.596288
# __________________________
# /opt/tljh/user/lib/python3.7/site-packages/ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Year of Interest:2011
#                                          CoC Name  sheltered es ratio
# 277                Cincinnati/Hamilton County CoC            0.402353
# 278                       Toledo/Lucas County CoC            0.392336
# 279                 Cleveland/Cuyahoga County CoC            0.518126
# 280                  Columbus/Franklin County CoC            0.762341
# 281                Youngstown/Mahoning County CoC            0.502242
# 282       Dayton, Kettering/Montgomery County CoC            0.576065
# 283            Akron, Barberton/Summit County CoC            0.403734
# 284                     Ohio Balance of State CoC            0.351388
# 285  Canton, Massillon, Alliance/Stark County CoC            0.452282
# __________________________
# /opt/tljh/user/lib/python3.7/site-packages/ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Year of Interest:2012
#                                          CoC Name  sheltered es ratio
# 276                Cincinnati/Hamilton County CoC            0.452842
# 277                       Toledo/Lucas County CoC            0.448311
# 278                 Cleveland/Cuyahoga County CoC            0.428571
# 279                  Columbus/Franklin County CoC            0.699442
# 280                Youngstown/Mahoning County CoC            0.566964
# 281       Dayton, Kettering/Montgomery County CoC            0.499537
# 282            Akron, Barberton/Summit County CoC            0.400984
# 283                     Ohio Balance of State CoC            0.380394
# 284  Canton, Massillon, Alliance/Stark County CoC            0.429461
# __________________________
# /opt/tljh/user/lib/python3.7/site-packages/ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Year of Interest:2013
#                                          CoC Name  sheltered es ratio
# 277                Cincinnati/Hamilton County CoC            0.479638
# 278                       Toledo/Lucas County CoC            0.537778
# 279                 Cleveland/Cuyahoga County CoC            0.534054
# 280                  Columbus/Franklin County CoC            0.682796
# 281                Youngstown/Mahoning County CoC            0.533040
# 282       Dayton, Kettering/Montgomery County CoC            0.591739
# 283            Akron, Barberton/Summit County CoC            0.400232
# 284                     Ohio Balance of State CoC            0.452742
# 285  Canton, Massillon, Alliance/Stark County CoC            0.473180
# __________________________
# /opt/tljh/user/lib/python3.7/site-packages/ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Year of Interest:2014
#                                          CoC Name  sheltered es ratio
# 277                Cincinnati/Hamilton County CoC            0.702780
# 278                       Toledo/Lucas County CoC            0.615575
# 279                 Cleveland/Cuyahoga County CoC            0.592962
# 280                  Columbus/Franklin County CoC            0.775093
# 281                Youngstown/Mahoning County CoC            0.593750
# 282       Dayton, Kettering/Montgomery County CoC            0.676359
# 283            Akron, Barberton/Summit County CoC            0.363218
# 284                     Ohio Balance of State CoC            0.539149
# 285  Canton, Massillon, Alliance/Stark County CoC            0.487759
# __________________________
# /opt/tljh/user/lib/python3.7/site-packages/ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Year of Interest:2015
#                                          CoC Name  sheltered es ratio
# 280                Cincinnati/Hamilton County CoC            0.665099
# 281                       Toledo/Lucas County CoC            0.721631
# 282                 Cleveland/Cuyahoga County CoC            0.644879
# 283                  Columbus/Franklin County CoC            0.805346
# 284                Youngstown/Mahoning County CoC            0.559783
# 285       Dayton, Kettering/Montgomery County CoC            0.681771
# 286            Akron, Barberton/Summit County CoC            0.448684
# 287                     Ohio Balance of State CoC            0.524398
# 288  Canton, Massillon, Alliance/Stark County CoC            0.506356
# __________________________
# /opt/tljh/user/lib/python3.7/site-packages/ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Year of Interest:2016
#                                          CoC Name  sheltered es ratio
# 279                Cincinnati/Hamilton County CoC            0.681900
# 280                       Toledo/Lucas County CoC            0.712855
# 281                 Cleveland/Cuyahoga County CoC            0.656453
# 282                  Columbus/Franklin County CoC            0.721578
# 283                Youngstown/Mahoning County CoC            0.638728
# 284       Dayton, Kettering/Montgomery County CoC            0.700399
# 285            Akron, Barberton/Summit County CoC            0.466863
# 286                     Ohio Balance of State CoC            0.539248
# 287  Canton, Massillon, Alliance/Stark County CoC            0.619565
# __________________________
# /opt/tljh/user/lib/python3.7/site-packages/ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Year of Interest:2017
#                                          CoC Name  sheltered es ratio
# 281                Cincinnati/Hamilton County CoC            0.713425
# 282                       Toledo/Lucas County CoC            0.693387
# 283                 Cleveland/Cuyahoga County CoC            0.819340
# 284                  Columbus/Franklin County CoC            0.726789
# 285                Youngstown/Mahoning County CoC            0.637405
# 286       Dayton, Kettering/Montgomery County CoC            0.722132
# 287            Akron, Barberton/Summit County CoC            0.506903
# 288                     Ohio Balance of State CoC            0.562103
# 289  Canton, Massillon, Alliance/Stark County CoC            0.655172
# __________________________
# /opt/tljh/user/lib/python3.7/site-packages/ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Year of Interest:2018
#                                          CoC Name  sheltered es ratio
# 281                Cincinnati/Hamilton County CoC            0.727110
# 282                       Toledo/Lucas County CoC            0.765861
# 283                 Cleveland/Cuyahoga County CoC            0.883296
# 284                  Columbus/Franklin County CoC            0.789707
# 285                Youngstown/Mahoning County CoC            0.827778
# 286       Dayton, Kettering/Montgomery County CoC            0.733824
# 287            Akron, Barberton/Summit County CoC            0.459966
# 288                     Ohio Balance of State CoC            0.559847
# 289  Canton, Massillon, Alliance/Stark County CoC            0.794964
# __________________________
# /opt/tljh/user/lib/python3.7/site-packages/ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Year of Interest:2019
#                                          CoC Name  sheltered es ratio
# 280                Cincinnati/Hamilton County CoC            0.799445
# 281                       Toledo/Lucas County CoC            0.823241
# 282                 Cleveland/Cuyahoga County CoC            0.870828
# 283                  Columbus/Franklin County CoC            0.758783
# 284                Youngstown/Mahoning County CoC            0.898649
# 285       Dayton, Kettering/Montgomery County CoC            0.775330
# 286            Akron, Barberton/Summit County CoC            0.492674
# 287                     Ohio Balance of State CoC            0.570566
# 288  Canton, Massillon, Alliance/Stark County CoC            0.890110
# __________________________
# /opt/tljh/user/lib/python3.7/site-packages/ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Year of Interest:2020
#                                          CoC Name  sheltered es ratio
# 280                Cincinnati/Hamilton County CoC            0.744505
# 281                       Toledo/Lucas County CoC            0.744186
# 282                 Cleveland/Cuyahoga County CoC            0.878806
# 283                  Columbus/Franklin County CoC            0.720039
# 284                Youngstown/Mahoning County CoC            0.780000
# 285       Dayton, Kettering/Montgomery County CoC            0.805707
# 286            Akron, Barberton/Summit County CoC            0.480409
# 287                     Ohio Balance of State CoC            0.534806
# 288  Canton, Massillon, Alliance/Stark County CoC            0.844000
# __________________________
# Year of Interest:2021
#                                          CoC Name  sheltered es ratio
# 281                Cincinnati/Hamilton County CoC            0.764764
# 282                       Toledo/Lucas County CoC            0.879896
# 283                 Cleveland/Cuyahoga County CoC            0.940912
# 284                  Columbus/Franklin County CoC            0.886447
# 285                Youngstown/Mahoning County CoC            0.903226
# 286       Dayton, Kettering/Montgomery County CoC            0.815141
# 287            Akron, Barberton/Summit County CoC            0.401015
# 288                     Ohio Balance of State CoC            0.785531
# 289  Canton, Massillon, Alliance/Stark County CoC            0.717949
# __________________________
# /opt/tljh/user/lib/python3.7/site-packages/ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
for key, val in county_name_ratios.items():
    plt.plot(year, val, label=key)
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)

plt.title('Percentage of the Homeless Population in ES Shelter, by Cities')
plt.xlabel('Years')
plt.ylabel('ES Sheltered Percentage')
# Out:
# Text(0, 0.5, 'ES Sheltered Percentage')
